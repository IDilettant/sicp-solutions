# %% [markdown]
# <h1 id="ch-1"># Chapter 1: Building Abstractions with Procedures
# </h1>

# %% [markdown]
# <h2 id="ex-1-1">Exercise 1.1</h2>

# %% [markdown]
# Below is a sequence of expressions. What is the result printed by the interpreter in response to each expression?

# %%
;; Exercise 1.1 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.1 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-2">Exercise 1.2</h2>

# %% [markdown]
# Translate the following expression into prefix form:
# $$\frac{5 + 4 + (2(9-(2+6)) + (2+6))}{3(6) + (4(3))}$$

# %%
;; Exercise 1.2 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.2 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-3">Exercise 1.3</h2>

# %% [markdown]
# Define a procedure that takes three numbers and returns the sum of squares of the two larger numbers.

# %%
;; Exercise 1.3 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.3 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-4">Exercise 1.4</h2>

# %% [markdown]
# Explain the behavior of procedure `(a-plus-abs-b a b)`.

# %%
;; Exercise 1.4 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.4 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-5">Exercise 1.5</h2>

# %% [markdown]
# Applicative vs normal-order evaluation experiment.

# %%
;; Exercise 1.5 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.5 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-6">Exercise 1.6</h2>

# %% [markdown]
# Discuss why using `new-if` breaks square root program.

# %%
;; Exercise 1.6 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.6 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-9">Exercise 1.9</h2>

# %% [markdown]
# Recursive vs iterative addition using inc/dec.

# %%
;; Exercise 1.9 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.9 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-11">Exercise 1.11</h2>

# %% [markdown]
# Compute f(n) recursively and iteratively.

# %%
;; Exercise 1.11 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.11 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-12">Exercise 1.12</h2>

# %% [markdown]
# Pascal’s triangle recursively.

# %%
;; Exercise 1.12 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.12 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-17">Exercise 1.17</h2>

# %% [markdown]
# Fast multiplication using doubling/halving.

# %%
;; Exercise 1.17 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.17 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-18">Exercise 1.18</h2>

# %% [markdown]
# Iterative multiplication using doubling/halving.

# %%
;; Exercise 1.18 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.18 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-19">Exercise 1.19</h2>

# %% [markdown]
# Logarithmic Fibonacci via transformation T.

# %%
;; Exercise 1.19 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.19 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-20">Exercise 1.20</h2>

# %% [markdown]
# Normal-order vs applicative-order gcd process.

# %%
;; Exercise 1.20 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.20 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-21">Exercise 1.21</h2>

# %% [markdown]
# Smallest divisors of 199, 1999, 19999.

# %%
;; Exercise 1.21 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.21 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-22">Exercise 1.22</h2>

# %% [markdown]
# Timed-prime test and performance experiments.

# %%
;; Exercise 1.22 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.22 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-24">Exercise 1.24</h2>

# %% [markdown]
# Fast-prime test (Fermat) performance comparison.

# %%
;; Exercise 1.24 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.24 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-25">Exercise 1.25</h2>

# %% [markdown]
# Discuss replacing expmod with fast-expt in Fermat test.

# %%
;; Exercise 1.25 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.25 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-26">Exercise 1.26</h2>

# %% [markdown]
# Why Louis's version of expmod makes complexity linear.

# %%
;; Exercise 1.26 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.26 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-27">Exercise 1.27</h2>

# %% [markdown]
# Carmichael numbers and Fermat test failure.

# %%
;; Exercise 1.27 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.27 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-28">Exercise 1.28</h2>

# %% [markdown]
# Miller–Rabin primality test implementation.

# %%
;; Exercise 1.28 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.28 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-30">Exercise 1.30</h2>

# %% [markdown]
# Iterative sum procedure.

# %%
;; Exercise 1.30 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.30 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-31">Exercise 1.31</h2>

# %% [markdown]
# Product procedure (recursive and iterative).

# %%
;; Exercise 1.31 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.31 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-32">Exercise 1.32</h2>

# %% [markdown]
# Accumulate abstraction.

# %%
;; Exercise 1.32 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.32 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-34">Exercise 1.34</h2>

# %% [markdown]
# Evaluate (f f).

# %%
;; Exercise 1.34 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.34 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-35">Exercise 1.35</h2>

# %% [markdown]
# Golden ratio as fixed point.

# %%
;; Exercise 1.35 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.35 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-36">Exercise 1.36</h2>

# %% [markdown]
# Fixed-point traces & solving x^x = 1000.

# %%
;; Exercise 1.36 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.36 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-38">Exercise 1.38</h2>

# %% [markdown]
# Euler continued fraction approximation for e.

# %%
;; Exercise 1.38 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.38 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-39">Exercise 1.39</h2>

# %% [markdown]
# Continued fraction tangent function.

# %%
;; Exercise 1.39 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.39 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-40">Exercise 1.40</h2>

# %% [markdown]
# Cubic function for Newton’s method.

# %%
;; Exercise 1.40 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.40 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-41">Exercise 1.41</h2>

# %% [markdown]
# Double procedure and nested doubling.

# %%
;; Exercise 1.41 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.41 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-42">Exercise 1.42</h2>

# %% [markdown]
# Compose functions f and g.

# %%
;; Exercise 1.42 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.42 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-43">Exercise 1.43</h2>

# %% [markdown]
# Repeated composition of a procedure.

# %%
;; Exercise 1.43 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.43 — tests placeholder
;; TODO: implement tests

# %% [markdown]
# <h2 id="ex-1-45">Exercise 1.45</h2>

# %% [markdown]
# Finding nth roots via repeated average damping.

# %%
;; Exercise 1.45 — solution placeholder
;; TODO: implement

# %%
;; Exercise 1.45 — tests placeholder
;; TODO: implement tests
